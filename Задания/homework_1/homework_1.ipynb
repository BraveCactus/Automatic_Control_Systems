# %% [markdown]
# # Домашнее задание №1
# ## Анализ системы автоматического управления (САУ)
#
# ### **Основные определения**
#
# 1. **Записать основные определения по отношению к
# системе автоматического управления в
# технической системе, приведенной на видео
# (ссылка прилагается).**
#
# 2. **Построить структурную схему САУ. Дать
# описание.**
#
# 3. **Определить тип САУ**

# %% [markdown]
# ### Техническая система (ТС), по отношению к которой выполнить задание - ствол пушки танка. Дать ответ на вопрос, почему ТС является динамической.
#
# ### Провести анализ видео и дать в описательном виде следующие данные о САУ технической системы
#
# 1. Наименование САУ.
# 2. Объект управления.
# 3. Цель управления.
# 4. Название g(t), y(t), f(t), u(t), ГОС в терминах технической системы.
# 5. Тип САУ.
# 6. Названия основных элементов САУ (САУ, ЗУ, УУ, ДОС, ОУ: ИУ,Н) в
# терминах технической системы
